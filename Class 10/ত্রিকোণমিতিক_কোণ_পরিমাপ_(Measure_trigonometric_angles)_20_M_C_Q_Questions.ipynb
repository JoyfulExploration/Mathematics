# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# ![Double Click.png](data:image/png;base64,...)
# <!--
# Answer: b
# -->

# %% [markdown]
# ![2.png](data:image/png;base64,...)
